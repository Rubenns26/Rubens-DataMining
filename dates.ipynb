# %% [markdown]
# <a href="https://colab.research.google.com/github/Rubenns26/Rubens-DataMining/blob/main/dates.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/drive/MyDrive/Data-mining/dates.csv', encoding='latin1')

# %%
df.head(1)
# Out:
#    key      My_date
# 0    1  Feb 1, 2002

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   key      150 non-null    int64
#  1   My_date  150 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 2.5+ KB

# %%
df['My_date'] = pd.to_datetime(df['My_date'], format='%b %d, %Y')

# %%
df['My_date'] = df['My_date'].dt.strftime('%Y/%m/%d')

# %%
df.head(5)
# Out:
#    key     My_date
# 0    1  2002/02/01
# 1    2  2021/08/01
# 2    3  2003/10/01
# 3    4  2004/08/05
# 4    5  2005/11/14

# %%
df.to_csv('/content/drive/MyDrive/Data-mining/datesn.csv', index=False)
